# %% [markdown]
# <a href="https://colab.research.google.com/github/ayubj/projek/blob/main/proyek_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameter-parameter fisika
g = 9.81  # percepatan gravitasi (m/s^2)
h = 100    # tinggi awal (meter)
v0 = 0     # kecepatan awal (m/s)

# Waktu simulasi
t_max = np.sqrt(2*h/g)  # waktu yang dibutuhkan untuk jatuh bebas
t = np.linspace(0, t_max, 500)  # waktu diskrit

# Posisi dan kecepatan benda
y = h - 0.5 * g * t**2  # posisi benda pada waktu t
v = -g * t  # kecepatan benda pada waktu t

# Plot posisi vs waktu
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(t, y)
plt.title('Posisi Benda vs Waktu')
plt.xlabel('Waktu (detik)')
plt.ylabel('Posisi (meter)')

# Plot kecepatan vs waktu
plt.subplot(1, 2, 2)
plt.plot(t, v, color='r')
plt.title('Kecepatan Benda vs Waktu')
plt.xlabel('Waktu (detik)')
plt.ylabel('Kecepatan (m/s)')

plt.tight_layout()
plt.show()

# %%
# !git add .
# !git commit -m "Menambahkan simulasi gerakan benda jatuh"
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
